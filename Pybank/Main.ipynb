# Calculate the Total number of months included in the data set
print(len(Monthly_income))

# Initialize metric values
total_profit_losses = 0
Number_days = 0
average = 0

# Initialize minimum key-value pair
minimum_key = ""
minimum_value = 0

# initialize maximum key-value pair
maximum_key = ""
maximum_value = 0

#Iterate over key-value pairs of the dictionary
print()
for date, income in Monthly_income.items():
    print(f"Day: {date} | Income {income}")
    
# Cumulatively sum up the total profits/losses and count months
    total_profit_losses += int(income)
    Number_days += 1
    
# Logic to determine greatest profit and greatest losses
    if minimum_value == 0:
        minimum_value = income
        minimum_key = date
    elif income < minimum_value:
        minimum_value = income
        minimum_key = date, income
    
    if income > maximum_value:
        maximum_value = income
        maximum_key = date, income
        
    # Group Date by income
    if income > 0:
        profitable_months.append(date)
    elif income < 0:
        unprofitable_months.append(date)
        
    # Calculate the average monthly income in the dictionary
    average = round(total_profit_losses / Number_days, 2)


# Print the metrics
print()
print("Financial Analysis")
print("------------------------------")
print(f"Total Monthly Incomes: {total_profit_losses}")
print(f"Total number of Months: {Number_days}")
print(f"Average Monthly Income: {average}")
print(f"Largest Monthly Profit: {maximum_key}")
print(f"Largest Monthly Loss: {minimum_key}")
      

# The net total amount of Profit/Losses over the entire period.


# The average of the changes in Profit/Losses over the entire period.


# The greatest increase in profits (date and amount) over the entire period.


# The greatest decrease in losses (date and amount) over the entire period
# Out:
# 86
#
# Day: Jan-2010 | Income 867884
# Day: Feb-2010 | Income 984655
# Day: Mar-2010 | Income 322013
# Day: Apr-2010 | Income -69417
# Day: May-2010 | Income 310503
# Day: Jun-2010 | Income 522857
# Day: Jul-2010 | Income 1033096
# Day: Aug-2010 | Income 604885
# Day: Sep-2010 | Income -216386
# Day: Oct-2010 | Income 477532
# Day: Nov-2010 | Income 893810
# Day: Dec-2010 | Income -80353
# Day: Jan-2011 | Income 779806
# Day: Feb-2011 | Income -335203
# Day: Mar-2011 | Income 697845
# Day: Apr-2011 | Income 793163
# Day: May-2011 | Income 485070
# Day: Jun-2011 | Income 584122
# Day: Jul-2011 | Income 62729
# Day: Aug-2011 | Income 668179
# Day: Sep-2011 | Income 899906
# Day: Oct-2011 | Income 834719
# Day: Nov-2011 | Income 132003
# Day: Dec-2011 | Income 309978
# Day: Jan-2012 | Income -755566
# Day: Feb-2012 | Income 1170593
# Day: Mar-2012 | Income 252788
# Day: Apr-2012 | Income 1151518
# Day: May-2012 | Income 817256
# Day: Jun-2012 | Income 570757
# ...
